# %% [markdown]
# # Merging all datasets
#
# We have the following data:
# - Google data — monthly
# - Indep data — yearly
# - World dep variable data — yearly
# - MENA dep variable data — monthly
#
# ## what this code does:
# (1) combine Google data with MENA data and do a moving average of some sort for the yearly indep data, and:
#
# (2) combine to take an average of the Google data across a particular year and merge this with the indep data and world data

# %%
import numpy as np
import pandas as pd
import csv

# %%
df_final = pd.DataFrame()
dfs = []

file_names = ['Google Trends data/google_all_data_monthly.csv', 'Google Trends data/google_all_data_yearly.csv', 'Independent variable - WB/df_monthly.csv', 'Independent variable - WB/full_dataset_WB_edited.csv', 'Final dependent variable/mena_data.csv', 'Final dependent variable/world_data.csv']
for file_name in file_names:
    with open(file_name, 'r') as file:
        next(file)
        #data = csv.reader(file)
        #df0 = pd.DataFrame(data)
        #dfs.append(df0)
        dfs.append(pd.read_csv(file_name))

# %%
# append unrest index (MENA) to Google Data
merged_dfs_MENA = pd.merge(dfs[0], dfs[2], how="inner", left_on=["country_code", "date"], right_on=["economy", "Time"])

# datetime for dep variable dfs
dfs[4]['year'] = dfs[4]['year'].astype(str)
dfs[4]['month'] = dfs[4]['month'].astype(str)
dfs[4]['date'] = pd.to_datetime(dfs[4]['year'] + '-' + dfs[4]['month'], format='%Y-%m')
dfs[4]['date'] = dfs[4]['date'].astype(str)

merged_dfs_MENA = pd.merge(merged_dfs_MENA, dfs[4], how="inner", left_on=["country_code", "date"], right_on=["iso3" ,"date"])
merged_dfs_MENA.to_csv(r'merged_dfs_MENA.csv')
merged_dfs_MENA
# Out:
#       Unnamed: 0_x        date  hits     keyword geo_x  month_x  year_x  \
# 0             2378  2010-07-01   0.0     protest    DZ        7    2010
# 1             2608  2010-07-01   5.0  revolution    DZ        7    2010
# 2             2838  2010-07-01   0.0       riots    DZ        7    2010
# 3             3068  2010-07-01  33.0      strike    DZ        7    2010
# 4             3298  2010-07-01   0.0    violence    DZ        7    2010
# ...            ...         ...   ...         ...   ...      ...     ...
# 4503        210636  2019-07-01   1.0     protest    TN        7    2019
# 4504        210866  2019-07-01  11.0  revolution    TN        7    2019
# 4505        211096  2019-07-01   1.0       riots    TN        7    2019
# 4506        211326  2019-07-01   4.0      strike    TN        7    2019
# 4507        211556  2019-07-01   5.0    violence    TN        7    2019
#
#      country_x country_code  Unnamed: 0_y  ...   ST.INT.ARVL   ST.INT.DPRT  \
# 0      Algeria          DZA           242  ...           NaN           NaN
# 1      Algeria          DZA           242  ...           NaN           NaN
# 2      Algeria          DZA           242  ...           NaN           NaN
# 3      Algeria          DZA           242  ...           NaN           NaN
# 4      Algeria          DZA           242  ...           NaN           NaN
# ...        ...          ...           ...  ...           ...           ...
# 4503   Tunisia          TUN         23945  ...  8.393167e+06  2.537167e+06
# 4504   Tunisia          TUN         23945  ...  8.393167e+06  2.537167e+06
# 4505   Tunisia          TUN         23945  ...  8.393167e+06  2.537167e+06
# 4506   Tunisia          TUN         23945  ...  8.393167e+06  2.537167e+06
# 4507   Tunisia          TUN         23945  ...  8.393167e+06  2.537167e+06
#
#       geo_y  economy  Unnamed: 0  iso3  country_y  year_y  month_y  \
# 0        DZ      DZA         479   DZA    Algeria    2010        7
# 1        DZ      DZA         479   DZA    Algeria    2010        7
# 2        DZ      DZA         479   DZA    Algeria    2010        7
# 3        DZ      DZA         479   DZA    Algeria    2010        7
# 4        DZ      DZA         479   DZA    Algeria    2010        7
# ...     ...      ...         ...   ...        ...     ...      ...
# 4503     TN      TUN        1512   TUN    Tunisia    2019        7
# 4504     TN      TUN        1512   TUN    Tunisia    2019        7
# 4505     TN      TUN        1512   TUN    Tunisia    2019        7
# 4506     TN      TUN        1512   TUN    Tunisia    2019        7
# 4507     TN      TUN        1512   TUN    Tunisia    2019        7
#
#       unrest_index
# 0         0.024871
# 1         0.024871
# 2         0.024871
# 3         0.024871
# 4         0.024871
# ...            ...
# 4503      0.360317
# 4504      0.360317
# 4505      0.360317
# 4506      0.360317
# 4507      0.360317
#
# [4508 rows x 75 columns]

# %%
merged_dfs_world = pd.merge(dfs[1], dfs[3], how="inner", left_on=["country_code", "date"], right_on=["economy", "Time"])

# datetime for dep variable dfs
dfs[5]['year'] = dfs[5]['year'].astype(str)
dfs[5]['date'] = pd.to_datetime(dfs[5]['year'], format='%Y')
dfs[5]['date'] = dfs[5]['date'].astype(str)

merged_dfs_world = pd.merge(merged_dfs_world, dfs[5], how="inner", left_on=["country_code", "date"], right_on=["iso3" ,"date"])
merged_dfs_world.to_csv(r'merged_dfs_world.csv')
merged_dfs_world
# Out:
#      Unnamed: 0_x country_code        date      hits  Unnamed: 0_y  \
# 0              14          ABW  2019-01-01  0.800000          2278
# 1              28          AFG  2017-01-01  0.400000          2379
# 2              29          AFG  2018-01-01  0.408333          2378
# 3              30          AFG  2019-01-01  0.500000          2377
# 4              37          AGO  2010-01-01  1.604167          2331
# ..            ...          ...         ...       ...           ...
# 588          3562          ZWE  2015-01-01  3.048611             5
# 589          3563          ZWE  2016-01-01  3.159722             4
# 590          3564          ZWE  2017-01-01  4.375000             3
# 591          3565          ZWE  2018-01-01  3.111111             2
# 592          3566          ZWE  2019-01-01  3.402778             1
#
#          Country        Time  BN.CAB.XOKA.GD.ZS  BX.KLT.DINV.WD.GD.ZS  \
# 0          Aruba  2019-01-01           2.516995             -2.232924
# 1    Afghanistan  2017-01-01         -18.812615              0.272719
# 2    Afghanistan  2018-01-01         -21.156793              0.648440
# 3    Afghanistan  2019-01-01         -20.058384              0.123804
# 4         Angola  2010-01-01           9.187268             -3.950098
# ..           ...         ...                ...                   ...
# 588     Zimbabwe  2015-01-01          -7.998095              1.999687
# 589     Zimbabwe  2016-01-01          -3.394138              1.669274
# 590     Zimbabwe  2017-01-01          -1.542184              1.746885
# 591     Zimbabwe  2018-01-01          -4.039183              2.101721
# 592     Zimbabwe  2019-01-01           4.216114              1.142806
#
#      EG.CFT.ACCS.ZS  ...  SP.URB.TOTL.IN.ZS  ST.INT.ARVL  ST.INT.DPRT  geo  \
# 0               NaN  ...             43.546    1951000.0          NaN   AW
# 1              29.7  ...             25.250          NaN          NaN   AF
# 2              30.9  ...             25.495          NaN          NaN   AF
# 3              31.9  ...             25.754          NaN          NaN   AF
# 4              44.3  ...             59.783     425000.0          NaN   AO
# ..              ...  ...                ...          ...          ...  ...
# 588            29.5  ...             32.385    2057000.0    3393000.0   ZW
# 589            29.8  ...             32.296    2168000.0    3192000.0   ZW
# 590            29.8  ...             32.237    2423000.0    2768000.0   ZW
# 591            29.9  ...             32.209    2580000.0    2288000.0   ZW
# 592            30.1  ...             32.210    2294000.0    3275000.0   ZW
#
#      economy  Unnamed: 0  iso3      country  year  unrest_index
# 0        ABW        1095   ABW        Aruba  2019      0.000168
# 1        AFG         885   AFG  Afghanistan  2017      9.142620
# 2        AFG         960   AFG  Afghanistan  2018     11.513111
# 3        AFG        1096   AFG  Afghanistan  2019     12.389551
# 4        AGO         470   AGO       Angola  2010      0.001261
# ..       ...         ...   ...          ...   ...           ...
# 588      ZWE         813   ZWE     Zimbabwe  2015      0.035166
# 589      ZWE         884   ZWE     Zimbabwe  2016      0.088278
# 590      ZWE         959   ZWE     Zimbabwe  2017      0.098554
# 591      ZWE        1094   ZWE     Zimbabwe  2018      0.088772
# 592      ZWE        1230   ZWE     Zimbabwe  2019      0.093388
#
# [593 rows x 69 columns]
